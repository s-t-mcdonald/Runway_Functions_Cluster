# %%
import pandas as pd
import numpy as np
import datetime

from src.const import *
from src.feature_processing_functions import *
# from src.helpers import get_file_path

from src.data_processing_pipeline import process_data
from src.submodel_pipeline import train_all_submodels
from src.bridge_pipeline import run_bridge_pipeline
# from src.nn_pipeline import train_final_model
# Out:
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %% [markdown]
# # Define Train, Val, and Test Timestamps
#
# ### Small sample for illustrative purposes

# %%
train_labels_df = ensure_datetime(pd.read_csv(f"open_train_labels.csv.bz2"))
train_timestamps = sorted(list(train_labels_df['timestamp'].unique()))

val_labels_df = ensure_datetime(pd.read_csv(f"open_submission_format.csv"))
val_timestamps = sorted(list(val_labels_df['timestamp'].unique()))

test_labels_df = ensure_datetime(pd.read_csv(f"evaluation_test_labels.csv"))
test_timestamps = sorted(list(test_labels_df['timestamp'].unique()))

# %% [markdown]
# # Process Raw Data

# %%
process_data(train_timestamps, val_timestamps, test_timestamps)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 process_data(train_timestamps, val_timestamps, test_timestamps)
#
# NameError: name 'train_timestamps' is not defined

# %% [markdown]
# # Train Submodels

# %%
train_all_submodels()
# Out:
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.98375
# [1]	validation_0-auc:0.98697
# [2]	validation_0-auc:0.98770
# [3]	validation_0-auc:0.98824
# [4]	validation_0-auc:0.98813
# [5]	validation_0-auc:0.98871
# [6]	validation_0-auc:0.98832
# [7]	validation_0-auc:0.98801
# [8]	validation_0-auc:0.98787
# [9]	validation_0-auc:0.98720
# [10]	validation_0-auc:0.98804
# [11]	validation_0-auc:0.98941
# [12]	validation_0-auc:0.98908
# [13]	validation_0-auc:0.98965
# [14]	validation_0-auc:0.98969
# [15]	validation_0-auc:0.98999
# [16]	validation_0-auc:0.98963
# [17]	validation_0-auc:0.98930
# [18]	validation_0-auc:0.98900
# [19]	validation_0-auc:0.98875
# [20]	validation_0-auc:0.98842
# [21]	validation_0-auc:0.98840
# [22]	validation_0-auc:0.98857
# [23]	validation_0-auc:0.98809
# [24]	validation_0-auc:0.98833
# [25]	validation_0-auc:0.98839
# D_26L_27R_A_26R_27L_28 1 0.9899867957746478
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.98934
# [1]	validation_0-auc:0.98964
# [2]	validation_0-auc:0.99376
# [3]	validation_0-auc:0.99579
# [4]	validation_0-auc:0.99515
# [5]	validation_0-auc:0.99521
# [6]	validation_0-auc:0.99497
# [7]	validation_0-auc:0.99513
# [8]	validation_0-auc:0.99600
# [9]	validation_0-auc:0.99622
# [10]	validation_0-auc:0.99602
# [11]	validation_0-auc:0.99568
# [12]	validation_0-auc:0.99551
# [13]	validation_0-auc:0.99544
# [14]	validation_0-auc:0.99534
# [15]	validation_0-auc:0.99487
# [16]	validation_0-auc:0.99472
# [17]	validation_0-auc:0.99453
# [18]	validation_0-auc:0.99435
# [19]	validation_0-auc:0.99423
# D_8R_9L_A_10_8L_9R 1 0.9962185162832982
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.95863
# [1]	validation_0-auc:0.97526
# [2]	validation_0-auc:0.97975
# [3]	validation_0-auc:0.97620
# [4]	validation_0-auc:0.97749
# [5]	validation_0-auc:0.97669
# [6]	validation_0-auc:0.97904
# [7]	validation_0-auc:0.97931
# [8]	validation_0-auc:0.97911
# [9]	validation_0-auc:0.97893
# [10]	validation_0-auc:0.97856
# [11]	validation_0-auc:0.97888
# [12]	validation_0-auc:0.97943
# other 1 0.979747386759582
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:1.00000
# [1]	validation_0-auc:1.00000
# [2]	validation_0-auc:1.00000
# [3]	validation_0-auc:1.00000
# [4]	validation_0-auc:1.00000
# [5]	validation_0-auc:1.00000
# [6]	validation_0-auc:1.00000
# [7]	validation_0-auc:1.00000
# [8]	validation_0-auc:1.00000
# [9]	validation_0-auc:1.00000
# D_26L_27R_28_A_26R_27L_28 1 1.0
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.71492
# [1]	validation_0-auc:0.71813
# [2]	validation_0-auc:0.72194
# [3]	validation_0-auc:0.72565
# [4]	validation_0-auc:0.71915
# [5]	validation_0-auc:0.72329
# [6]	validation_0-auc:0.74106
# [7]	validation_0-auc:0.74386
# [8]	validation_0-auc:0.76073
# [9]	validation_0-auc:0.76955
# [10]	validation_0-auc:0.76092
# [11]	validation_0-auc:0.76597
# [12]	validation_0-auc:0.77239
# [13]	validation_0-auc:0.77395
# [14]	validation_0-auc:0.77901
# [15]	validation_0-auc:0.77069
# [16]	validation_0-auc:0.76956
# [17]	validation_0-auc:0.76855
# [18]	validation_0-auc:0.77666
# [19]	validation_0-auc:0.77570
# [20]	validation_0-auc:0.77392
# [21]	validation_0-auc:0.76887
# [22]	validation_0-auc:0.76571
# [23]	validation_0-auc:0.76434
# [24]	validation_0-auc:0.76763
# 1 0.7790082809538061
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.96937
# [1]	validation_0-auc:0.97346
# [2]	validation_0-auc:0.97169
# [3]	validation_0-auc:0.97248
# [4]	validation_0-auc:0.97846
# [5]	validation_0-auc:0.97846
# [6]	validation_0-auc:0.97854
# [7]	validation_0-auc:0.97685
# [8]	validation_0-auc:0.97658
# [9]	validation_0-auc:0.97588
# [10]	validation_0-auc:0.97644
# [11]	validation_0-auc:0.97502
# [12]	validation_0-auc:0.97421
# [13]	validation_0-auc:0.97452
# [14]	validation_0-auc:0.97460
# [15]	validation_0-auc:0.97525
# [16]	validation_0-auc:0.97463
# D_26L_27R_A_26R_27L_28 2 0.9785370889609715
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.97357
# [1]	validation_0-auc:0.97693
# [2]	validation_0-auc:0.97683
# [3]	validation_0-auc:0.97657
# [4]	validation_0-auc:0.97709
# [5]	validation_0-auc:0.97952
# [6]	validation_0-auc:0.98522
# [7]	validation_0-auc:0.98661
# [8]	validation_0-auc:0.98757
# [9]	validation_0-auc:0.98810
# [10]	validation_0-auc:0.98861
# [11]	validation_0-auc:0.98802
# [12]	validation_0-auc:0.98803
# [13]	validation_0-auc:0.98760
# [14]	validation_0-auc:0.98732
# [15]	validation_0-auc:0.98764
# [16]	validation_0-auc:0.98794
# [17]	validation_0-auc:0.98857
# [18]	validation_0-auc:0.98828
# [19]	validation_0-auc:0.98868
# [20]	validation_0-auc:0.98813
# [21]	validation_0-auc:0.98806
# [22]	validation_0-auc:0.98790
# [23]	validation_0-auc:0.98793
# [24]	validation_0-auc:0.98820
# [25]	validation_0-auc:0.98884
# [26]	validation_0-auc:0.98875
# [27]	validation_0-auc:0.98852
# [28]	validation_0-auc:0.98864
# [29]	validation_0-auc:0.98903
# [30]	validation_0-auc:0.98928
# [31]	validation_0-auc:0.98944
# [32]	validation_0-auc:0.98940
# [33]	validation_0-auc:0.98994
# [34]	validation_0-auc:0.98972
# [35]	validation_0-auc:0.98963
# [36]	validation_0-auc:0.98963
# [37]	validation_0-auc:0.98971
# [38]	validation_0-auc:0.98972
# [39]	validation_0-auc:0.98975
# [40]	validation_0-auc:0.98971
# [41]	validation_0-auc:0.98988
# [42]	validation_0-auc:0.98969
# D_8R_9L_A_10_8L_9R 2 0.9899389615052596
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.97341
# [1]	validation_0-auc:0.97940
# [2]	validation_0-auc:0.97938
# [3]	validation_0-auc:0.97769
# [4]	validation_0-auc:0.97887
# [5]	validation_0-auc:0.97874
# [6]	validation_0-auc:0.97817
# [7]	validation_0-auc:0.97904
# [8]	validation_0-auc:0.97803
# [9]	validation_0-auc:0.97712
# [10]	validation_0-auc:0.97656
# other 2 0.9794004076830016
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.95703
# [1]	validation_0-auc:0.95690
# [2]	validation_0-auc:0.95706
# [3]	validation_0-auc:0.95685
# [4]	validation_0-auc:0.95711
# [5]	validation_0-auc:0.95706
# [6]	validation_0-auc:0.95717
# [7]	validation_0-auc:0.95711
# [8]	validation_0-auc:0.99690
# [9]	validation_0-auc:0.99666
# [10]	validation_0-auc:0.99719
# [11]	validation_0-auc:0.99740
# [12]	validation_0-auc:0.99785
# [13]	validation_0-auc:0.99775
# [14]	validation_0-auc:0.99775
# [15]	validation_0-auc:0.99780
# [16]	validation_0-auc:0.99764
# [17]	validation_0-auc:0.99759
# [18]	validation_0-auc:0.99753
# [19]	validation_0-auc:0.99780
# [20]	validation_0-auc:0.99772
# [21]	validation_0-auc:0.99777
# [22]	validation_0-auc:0.99788
# [23]	validation_0-auc:0.99777
# [24]	validation_0-auc:0.99751
# [25]	validation_0-auc:0.99772
# [26]	validation_0-auc:0.99762
# [27]	validation_0-auc:0.99767
# [28]	validation_0-auc:0.99767
# [29]	validation_0-auc:0.99756
# [30]	validation_0-auc:0.99767
# [31]	validation_0-auc:0.99767
# D_26L_27R_28_A_26R_27L_28 2 0.9978795589482612
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.76431
# [1]	validation_0-auc:0.79415
# [2]	validation_0-auc:0.80296
# [3]	validation_0-auc:0.81227
# [4]	validation_0-auc:0.81280
# [5]	validation_0-auc:0.81395
# [6]	validation_0-auc:0.82826
# [7]	validation_0-auc:0.81709
# [8]	validation_0-auc:0.81629
# [9]	validation_0-auc:0.81712
# [10]	validation_0-auc:0.82163
# [11]	validation_0-auc:0.82446
# [12]	validation_0-auc:0.81697
# [13]	validation_0-auc:0.81458
# [14]	validation_0-auc:0.81202
# [15]	validation_0-auc:0.81174
# 2 0.8282600842865744
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.95493
# [1]	validation_0-auc:0.95927
# [2]	validation_0-auc:0.96138
# [3]	validation_0-auc:0.96471
# [4]	validation_0-auc:0.96353
# [5]	validation_0-auc:0.96149
# [6]	validation_0-auc:0.96261
# [7]	validation_0-auc:0.96140
# [8]	validation_0-auc:0.96456
# [9]	validation_0-auc:0.96433
# [10]	validation_0-auc:0.96407
# [11]	validation_0-auc:0.96524
# [12]	validation_0-auc:0.96600
# [13]	validation_0-auc:0.96505
# [14]	validation_0-auc:0.96681
# [15]	validation_0-auc:0.96675
# [16]	validation_0-auc:0.96751
# [17]	validation_0-auc:0.96688
# [18]	validation_0-auc:0.96657
# [19]	validation_0-auc:0.96769
# [20]	validation_0-auc:0.96734
# [21]	validation_0-auc:0.96682
# [22]	validation_0-auc:0.96525
# [23]	validation_0-auc:0.96683
# [24]	validation_0-auc:0.96716
# [25]	validation_0-auc:0.96760
# [26]	validation_0-auc:0.96680
# [27]	validation_0-auc:0.96691
# [28]	validation_0-auc:0.96641
# D_26L_27R_A_26R_27L_28 3 0.9676899012611204
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.96798
# [1]	validation_0-auc:0.96637
# [2]	validation_0-auc:0.96694
# [3]	validation_0-auc:0.96854
# [4]	validation_0-auc:0.97238
# [5]	validation_0-auc:0.97362
# [6]	validation_0-auc:0.97404
# [7]	validation_0-auc:0.97805
# [8]	validation_0-auc:0.97899
# [9]	validation_0-auc:0.97968
# [10]	validation_0-auc:0.98006
# [11]	validation_0-auc:0.98050
# [12]	validation_0-auc:0.98074
# [13]	validation_0-auc:0.98068
# [14]	validation_0-auc:0.98304
# [15]	validation_0-auc:0.98340
# [16]	validation_0-auc:0.98329
# [17]	validation_0-auc:0.98290
# [18]	validation_0-auc:0.98235
# [19]	validation_0-auc:0.98217
# [20]	validation_0-auc:0.98203
# [21]	validation_0-auc:0.98228
# [22]	validation_0-auc:0.98226
# [23]	validation_0-auc:0.98234
# [24]	validation_0-auc:0.98270
# [25]	validation_0-auc:0.98365
# [26]	validation_0-auc:0.98386
# [27]	validation_0-auc:0.98362
# [28]	validation_0-auc:0.98354
# [29]	validation_0-auc:0.98351
# [30]	validation_0-auc:0.98330
# [31]	validation_0-auc:0.98301
# [32]	validation_0-auc:0.98291
# [33]	validation_0-auc:0.98308
# [34]	validation_0-auc:0.98313
# [35]	validation_0-auc:0.98311
# [36]	validation_0-auc:0.98327
# D_8R_9L_A_10_8L_9R 3 0.9838632478632479
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.95572
# [1]	validation_0-auc:0.95876
# [2]	validation_0-auc:0.96042
# [3]	validation_0-auc:0.96180
# [4]	validation_0-auc:0.96123
# [5]	validation_0-auc:0.96051
# [6]	validation_0-auc:0.96027
# [7]	validation_0-auc:0.95709
# [8]	validation_0-auc:0.95503
# [9]	validation_0-auc:0.95226
# [10]	validation_0-auc:0.95229
# [11]	validation_0-auc:0.95285
# [12]	validation_0-auc:0.94970
# [13]	validation_0-auc:0.94776
# other 3 0.9617979452054795
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.95696
# [1]	validation_0-auc:0.95738
# [2]	validation_0-auc:0.95743
# [3]	validation_0-auc:0.95743
# [4]	validation_0-auc:0.95743
# [5]	validation_0-auc:0.95743
# [6]	validation_0-auc:0.97699
# [7]	validation_0-auc:0.97678
# [8]	validation_0-auc:0.99632
# [9]	validation_0-auc:0.99762
# [10]	validation_0-auc:0.99735
# [11]	validation_0-auc:0.99772
# [12]	validation_0-auc:0.99764
# [13]	validation_0-auc:0.99780
# [14]	validation_0-auc:0.99769
# [15]	validation_0-auc:0.99788
# [16]	validation_0-auc:0.99788
# [17]	validation_0-auc:0.99777
# [18]	validation_0-auc:0.99751
# [19]	validation_0-auc:0.99756
# [20]	validation_0-auc:0.99703
# [21]	validation_0-auc:0.99655
# [22]	validation_0-auc:0.99640
# [23]	validation_0-auc:0.99618
# [24]	validation_0-auc:0.99581
# D_26L_27R_28_A_26R_27L_28 3 0.9978795589482612
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.68341
# [1]	validation_0-auc:0.69118
# [2]	validation_0-auc:0.69437
# [3]	validation_0-auc:0.69334
# [4]	validation_0-auc:0.69168
# [5]	validation_0-auc:0.69325
# [6]	validation_0-auc:0.69904
# [7]	validation_0-auc:0.70528
# [8]	validation_0-auc:0.71936
# [9]	validation_0-auc:0.70423
# [10]	validation_0-auc:0.72608
# [11]	validation_0-auc:0.72418
# [12]	validation_0-auc:0.71120
# [13]	validation_0-auc:0.71725
# [14]	validation_0-auc:0.73252
# [15]	validation_0-auc:0.73323
# [16]	validation_0-auc:0.72907
# [17]	validation_0-auc:0.72625
# [18]	validation_0-auc:0.72616
# [19]	validation_0-auc:0.72733
# [20]	validation_0-auc:0.72480
# [21]	validation_0-auc:0.71978
# [22]	validation_0-auc:0.73005
# [23]	validation_0-auc:0.72849
# [24]	validation_0-auc:0.73185
# 3 0.7332302371212878
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.93665
# [1]	validation_0-auc:0.94667
# [2]	validation_0-auc:0.94843
# [3]	validation_0-auc:0.95377
# [4]	validation_0-auc:0.95516
# [5]	validation_0-auc:0.95687
# [6]	validation_0-auc:0.95832
# [7]	validation_0-auc:0.95659
# [8]	validation_0-auc:0.95721
# [9]	validation_0-auc:0.95751
# [10]	validation_0-auc:0.95867
# [11]	validation_0-auc:0.95889
# [12]	validation_0-auc:0.95818
# [13]	validation_0-auc:0.95860
# [14]	validation_0-auc:0.95929
# [15]	validation_0-auc:0.95905
# [16]	validation_0-auc:0.95920
# [17]	validation_0-auc:0.95909
# [18]	validation_0-auc:0.95885
# [19]	validation_0-auc:0.95859
# [20]	validation_0-auc:0.95733
# [21]	validation_0-auc:0.95657
# [22]	validation_0-auc:0.95564
# [23]	validation_0-auc:0.95627
# D_26L_27R_A_26R_27L_28 4 0.9592932728416246
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.94352
# [1]	validation_0-auc:0.95207
# [2]	validation_0-auc:0.96365
# [3]	validation_0-auc:0.96637
# [4]	validation_0-auc:0.96664
# [5]	validation_0-auc:0.97114
# [6]	validation_0-auc:0.97188
# [7]	validation_0-auc:0.97215
# [8]	validation_0-auc:0.97114
# [9]	validation_0-auc:0.97170
# [10]	validation_0-auc:0.97181
# [11]	validation_0-auc:0.97332
# [12]	validation_0-auc:0.97267
# [13]	validation_0-auc:0.97252
# [14]	validation_0-auc:0.97189
# [15]	validation_0-auc:0.97225
# [16]	validation_0-auc:0.97209
# [17]	validation_0-auc:0.97266
# [18]	validation_0-auc:0.97425
# [19]	validation_0-auc:0.97447
# [20]	validation_0-auc:0.97414
# [21]	validation_0-auc:0.97384
# [22]	validation_0-auc:0.97468
# [23]	validation_0-auc:0.97434
# [24]	validation_0-auc:0.97422
# [25]	validation_0-auc:0.97392
# [26]	validation_0-auc:0.97337
# [27]	validation_0-auc:0.97330
# [28]	validation_0-auc:0.97342
# [29]	validation_0-auc:0.97371
# [30]	validation_0-auc:0.97299
# [31]	validation_0-auc:0.97292
# D_8R_9L_A_10_8L_9R 4 0.9746780626780627
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.92998
# [1]	validation_0-auc:0.93422
# [2]	validation_0-auc:0.93814
# [3]	validation_0-auc:0.94007
# [4]	validation_0-auc:0.94407
# [5]	validation_0-auc:0.94440
# [6]	validation_0-auc:0.94644
# [7]	validation_0-auc:0.94509
# [8]	validation_0-auc:0.94964
# [9]	validation_0-auc:0.94811
# [10]	validation_0-auc:0.94640
# [11]	validation_0-auc:0.94275
# [12]	validation_0-auc:0.94663
# [13]	validation_0-auc:0.94571
# [14]	validation_0-auc:0.94223
# [15]	validation_0-auc:0.94118
# [16]	validation_0-auc:0.93853
# [17]	validation_0-auc:0.94022
# other 4 0.9496350488577283
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.91489
# [1]	validation_0-auc:0.91444
# [2]	validation_0-auc:0.91439
# [3]	validation_0-auc:0.99197
# [4]	validation_0-auc:0.99428
# [5]	validation_0-auc:0.99539
# [6]	validation_0-auc:0.99502
# [7]	validation_0-auc:0.99486
# [8]	validation_0-auc:0.99465
# [9]	validation_0-auc:0.99478
# [10]	validation_0-auc:0.99457
# [11]	validation_0-auc:0.99435
# [12]	validation_0-auc:0.99420
# [13]	validation_0-auc:0.99441
# [14]	validation_0-auc:0.99472
# [15]	validation_0-auc:0.99451
# D_26L_27R_28_A_26R_27L_28 4 0.9953880407124682
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.66849
# [1]	validation_0-auc:0.73388
# [2]	validation_0-auc:0.74738
# [3]	validation_0-auc:0.74512
# [4]	validation_0-auc:0.74490
# [5]	validation_0-auc:0.76313
# [6]	validation_0-auc:0.79544
# [7]	validation_0-auc:0.79964
# [8]	validation_0-auc:0.80147
# [9]	validation_0-auc:0.79812
# [10]	validation_0-auc:0.79166
# [11]	validation_0-auc:0.79673
# [12]	validation_0-auc:0.79383
# [13]	validation_0-auc:0.78881
# [14]	validation_0-auc:0.79370
# [15]	validation_0-auc:0.79028
# [16]	validation_0-auc:0.79566
# [17]	validation_0-auc:0.80242
# [18]	validation_0-auc:0.80807
# [19]	validation_0-auc:0.80251
# [20]	validation_0-auc:0.79790
# [21]	validation_0-auc:0.79825
# [22]	validation_0-auc:0.79804
# [23]	validation_0-auc:0.79529
# [24]	validation_0-auc:0.79464
# [25]	validation_0-auc:0.79390
# [26]	validation_0-auc:0.79626
# [27]	validation_0-auc:0.79751
# [28]	validation_0-auc:0.79823
# 4 0.8080674292594822
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.89429
# [1]	validation_0-auc:0.92436
# [2]	validation_0-auc:0.93378
# [3]	validation_0-auc:0.93530
# [4]	validation_0-auc:0.94017
# [5]	validation_0-auc:0.94283
# [6]	validation_0-auc:0.94314
# [7]	validation_0-auc:0.94255
# [8]	validation_0-auc:0.94145
# [9]	validation_0-auc:0.94282
# [10]	validation_0-auc:0.94215
# [11]	validation_0-auc:0.94020
# [12]	validation_0-auc:0.94130
# [13]	validation_0-auc:0.94114
# [14]	validation_0-auc:0.94028
# [15]	validation_0-auc:0.94144
# [16]	validation_0-auc:0.94173
# D_26L_27R_A_26R_27L_28 5 0.9431401768700836
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.92619
# [1]	validation_0-auc:0.95436
# [2]	validation_0-auc:0.96154
# [3]	validation_0-auc:0.96243
# [4]	validation_0-auc:0.96252
# [5]	validation_0-auc:0.96529
# [6]	validation_0-auc:0.96522
# [7]	validation_0-auc:0.96534
# [8]	validation_0-auc:0.96548
# [9]	validation_0-auc:0.96522
# [10]	validation_0-auc:0.96537
# [11]	validation_0-auc:0.96431
# [12]	validation_0-auc:0.96511
# [13]	validation_0-auc:0.96596
# [14]	validation_0-auc:0.96586
# [15]	validation_0-auc:0.96437
# [16]	validation_0-auc:0.96417
# [17]	validation_0-auc:0.96357
# [18]	validation_0-auc:0.96454
# [19]	validation_0-auc:0.96411
# [20]	validation_0-auc:0.96443
# [21]	validation_0-auc:0.96544
# [22]	validation_0-auc:0.96470
# [23]	validation_0-auc:0.96362
# D_8R_9L_A_10_8L_9R 5 0.9659591509811774
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.91626
# [1]	validation_0-auc:0.91958
# [2]	validation_0-auc:0.92149
# [3]	validation_0-auc:0.92175
# [4]	validation_0-auc:0.92539
# [5]	validation_0-auc:0.92517
# [6]	validation_0-auc:0.93104
# [7]	validation_0-auc:0.92576
# [8]	validation_0-auc:0.92862
# [9]	validation_0-auc:0.92414
# [10]	validation_0-auc:0.92226
# [11]	validation_0-auc:0.92097
# [12]	validation_0-auc:0.91903
# [13]	validation_0-auc:0.92425
# [14]	validation_0-auc:0.91828
# [15]	validation_0-auc:0.92128
# other 5 0.9310372005044136
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.91447
# [1]	validation_0-auc:0.91500
# [2]	validation_0-auc:0.91492
# [3]	validation_0-auc:0.99398
# [4]	validation_0-auc:0.99364
# [5]	validation_0-auc:0.99414
# [6]	validation_0-auc:0.99499
# [7]	validation_0-auc:0.99504
# [8]	validation_0-auc:0.99472
# [9]	validation_0-auc:0.99502
# [10]	validation_0-auc:0.99496
# [11]	validation_0-auc:0.99502
# [12]	validation_0-auc:0.99502
# [13]	validation_0-auc:0.99499
# [14]	validation_0-auc:0.99483
# [15]	validation_0-auc:0.99528
# [16]	validation_0-auc:0.99162
# [17]	validation_0-auc:0.99438
# [18]	validation_0-auc:0.99549
# [19]	validation_0-auc:0.99507
# [20]	validation_0-auc:0.99544
# [21]	validation_0-auc:0.99502
# [22]	validation_0-auc:0.99478
# [23]	validation_0-auc:0.99433
# [24]	validation_0-auc:0.99433
# [25]	validation_0-auc:0.99369
# [26]	validation_0-auc:0.99343
# [27]	validation_0-auc:0.99422
# [28]	validation_0-auc:0.99422
# D_26L_27R_28_A_26R_27L_28 5 0.9954940627650551
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.70099
# [1]	validation_0-auc:0.68453
# [2]	validation_0-auc:0.69352
# [3]	validation_0-auc:0.66336
# [4]	validation_0-auc:0.68295
# [5]	validation_0-auc:0.68042
# [6]	validation_0-auc:0.66860
# [7]	validation_0-auc:0.68473
# [8]	validation_0-auc:0.69683
# [9]	validation_0-auc:0.69212
# [10]	validation_0-auc:0.70995
# [11]	validation_0-auc:0.69212
# [12]	validation_0-auc:0.69773
# [13]	validation_0-auc:0.69442
# [14]	validation_0-auc:0.72192
# [15]	validation_0-auc:0.70606
# [16]	validation_0-auc:0.70390
# [17]	validation_0-auc:0.70865
# [18]	validation_0-auc:0.71115
# [19]	validation_0-auc:0.71211
# [20]	validation_0-auc:0.70756
# [21]	validation_0-auc:0.71381
# [22]	validation_0-auc:0.71753
# [23]	validation_0-auc:0.71321
# 5 0.721922910638864
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.90507
# [1]	validation_0-auc:0.91426
# [2]	validation_0-auc:0.92737
# [3]	validation_0-auc:0.92718
# [4]	validation_0-auc:0.92643
# [5]	validation_0-auc:0.93036
# [6]	validation_0-auc:0.92857
# [7]	validation_0-auc:0.92858
# [8]	validation_0-auc:0.92912
# [9]	validation_0-auc:0.93040
# [10]	validation_0-auc:0.92952
# [11]	validation_0-auc:0.93281
# [12]	validation_0-auc:0.93318
# [13]	validation_0-auc:0.93522
# [14]	validation_0-auc:0.93406
# [15]	validation_0-auc:0.93385
# [16]	validation_0-auc:0.93282
# [17]	validation_0-auc:0.93263
# [18]	validation_0-auc:0.92977
# [19]	validation_0-auc:0.92867
# [20]	validation_0-auc:0.92731
# [21]	validation_0-auc:0.92831
# [22]	validation_0-auc:0.92872
# [23]	validation_0-auc:0.93061
# D_26L_27R_A_26R_27L_28 6 0.935215987401498
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.92587
# [1]	validation_0-auc:0.93643
# [2]	validation_0-auc:0.94907
# [3]	validation_0-auc:0.95072
# [4]	validation_0-auc:0.95472
# [5]	validation_0-auc:0.95702
# [6]	validation_0-auc:0.95750
# [7]	validation_0-auc:0.95805
# [8]	validation_0-auc:0.95731
# [9]	validation_0-auc:0.95772
# [10]	validation_0-auc:0.95790
# [11]	validation_0-auc:0.95684
# [12]	validation_0-auc:0.95792
# [13]	validation_0-auc:0.95729
# [14]	validation_0-auc:0.95691
# [15]	validation_0-auc:0.95570
# [16]	validation_0-auc:0.95533
# D_8R_9L_A_10_8L_9R 6 0.9580515486508338
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.84750
# [1]	validation_0-auc:0.86227
# [2]	validation_0-auc:0.87785
# [3]	validation_0-auc:0.88668
# [4]	validation_0-auc:0.89177
# [5]	validation_0-auc:0.90889
# [6]	validation_0-auc:0.91401
# [7]	validation_0-auc:0.92366
# [8]	validation_0-auc:0.92353
# [9]	validation_0-auc:0.92005
# [10]	validation_0-auc:0.92025
# [11]	validation_0-auc:0.91776
# [12]	validation_0-auc:0.91727
# [13]	validation_0-auc:0.91887
# [14]	validation_0-auc:0.92116
# [15]	validation_0-auc:0.92109
# [16]	validation_0-auc:0.91539
# [17]	validation_0-auc:0.90719
# other 6 0.923661015775165
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.87235
# [1]	validation_0-auc:0.99184
# [2]	validation_0-auc:0.99189
# [3]	validation_0-auc:0.99239
# [4]	validation_0-auc:0.99303
# [5]	validation_0-auc:0.99313
# [6]	validation_0-auc:0.99218
# [7]	validation_0-auc:0.99197
# [8]	validation_0-auc:0.99268
# [9]	validation_0-auc:0.99279
# [10]	validation_0-auc:0.99237
# [11]	validation_0-auc:0.99242
# [12]	validation_0-auc:0.99221
# [13]	validation_0-auc:0.99258
# [14]	validation_0-auc:0.99242
# [15]	validation_0-auc:0.99197
# D_26L_27R_28_A_26R_27L_28 6 0.9931350720949957
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.70521
# [1]	validation_0-auc:0.68165
# [2]	validation_0-auc:0.69606
# [3]	validation_0-auc:0.71734
# [4]	validation_0-auc:0.71677
# [5]	validation_0-auc:0.73304
# [6]	validation_0-auc:0.73432
# [7]	validation_0-auc:0.72029
# [8]	validation_0-auc:0.73066
# [9]	validation_0-auc:0.73528
# [10]	validation_0-auc:0.73494
# [11]	validation_0-auc:0.73528
# [12]	validation_0-auc:0.72222
# [13]	validation_0-auc:0.72907
# [14]	validation_0-auc:0.72562
# [15]	validation_0-auc:0.73031
# [16]	validation_0-auc:0.73975
# [17]	validation_0-auc:0.73704
# [18]	validation_0-auc:0.73198
# [19]	validation_0-auc:0.73107
# [20]	validation_0-auc:0.72592
# [21]	validation_0-auc:0.72878
# [22]	validation_0-auc:0.72531
# [23]	validation_0-auc:0.72691
# [24]	validation_0-auc:0.72154
# [25]	validation_0-auc:0.71998
# 6 0.7397471402769417
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.89036
# [1]	validation_0-auc:0.90657
# [2]	validation_0-auc:0.90709
# [3]	validation_0-auc:0.91329
# [4]	validation_0-auc:0.91303
# [5]	validation_0-auc:0.91308
# [6]	validation_0-auc:0.91305
# [7]	validation_0-auc:0.91449
# [8]	validation_0-auc:0.91082
# [9]	validation_0-auc:0.91291
# [10]	validation_0-auc:0.91278
# [11]	validation_0-auc:0.91373
# [12]	validation_0-auc:0.91552
# [13]	validation_0-auc:0.91830
# [14]	validation_0-auc:0.91788
# [15]	validation_0-auc:0.91839
# [16]	validation_0-auc:0.91784
# [17]	validation_0-auc:0.91739
# [18]	validation_0-auc:0.91714
# [19]	validation_0-auc:0.92012
# [20]	validation_0-auc:0.92016
# [21]	validation_0-auc:0.92044
# [22]	validation_0-auc:0.92120
# [23]	validation_0-auc:0.92051
# [24]	validation_0-auc:0.92167
# [25]	validation_0-auc:0.92021
# [26]	validation_0-auc:0.92083
# [27]	validation_0-auc:0.92132
# [28]	validation_0-auc:0.91883
# [29]	validation_0-auc:0.91861
# [30]	validation_0-auc:0.91827
# [31]	validation_0-auc:0.91771
# [32]	validation_0-auc:0.91775
# [33]	validation_0-auc:0.91696
# [34]	validation_0-auc:0.91878
# D_26L_27R_A_26R_27L_28 7 0.9216666666666666
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.91792
# [1]	validation_0-auc:0.93075
# [2]	validation_0-auc:0.93294
# [3]	validation_0-auc:0.94021
# [4]	validation_0-auc:0.94579
# [5]	validation_0-auc:0.94722
# [6]	validation_0-auc:0.94944
# [7]	validation_0-auc:0.94864
# [8]	validation_0-auc:0.94774
# [9]	validation_0-auc:0.95041
# [10]	validation_0-auc:0.94996
# [11]	validation_0-auc:0.95074
# [12]	validation_0-auc:0.95232
# [13]	validation_0-auc:0.95305
# [14]	validation_0-auc:0.95235
# [15]	validation_0-auc:0.95290
# [16]	validation_0-auc:0.95143
# [17]	validation_0-auc:0.94988
# [18]	validation_0-auc:0.95041
# ...
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.56496
# [1]	validation_0-auc:0.54965
# [2]	validation_0-auc:0.59337
# [3]	validation_0-auc:0.58529
# [4]	validation_0-auc:0.59882
# [5]	validation_0-auc:0.59350
# [6]	validation_0-auc:0.59807
# [7]	validation_0-auc:0.59178
# [8]	validation_0-auc:0.62162
# [9]	validation_0-auc:0.61238
# [10]	validation_0-auc:0.62165
# [11]	validation_0-auc:0.63596
# [12]	validation_0-auc:0.62209
# [13]	validation_0-auc:0.60465
# [14]	validation_0-auc:0.59158
# [15]	validation_0-auc:0.59744
# [16]	validation_0-auc:0.60420
# [17]	validation_0-auc:0.60862
# [18]	validation_0-auc:0.61370
# [19]	validation_0-auc:0.61840
# [20]	validation_0-auc:0.61907
# [21]	validation_0-auc:0.62515
# 10 0.6359630904343698
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.88003
# [1]	validation_0-auc:0.88492
# [2]	validation_0-auc:0.87637
# [3]	validation_0-auc:0.87045
# [4]	validation_0-auc:0.88227
# [5]	validation_0-auc:0.89544
# [6]	validation_0-auc:0.89225
# [7]	validation_0-auc:0.89906
# [8]	validation_0-auc:0.89696
# [9]	validation_0-auc:0.90245
# [10]	validation_0-auc:0.90557
# [11]	validation_0-auc:0.90775
# [12]	validation_0-auc:0.91321
# [13]	validation_0-auc:0.91833
# [14]	validation_0-auc:0.91780
# [15]	validation_0-auc:0.92006
# [16]	validation_0-auc:0.91840
# [17]	validation_0-auc:0.91669
# [18]	validation_0-auc:0.91754
# [19]	validation_0-auc:0.91848
# [20]	validation_0-auc:0.91724
# [21]	validation_0-auc:0.91775
# [22]	validation_0-auc:0.91709
# [23]	validation_0-auc:0.91505
# [24]	validation_0-auc:0.91360
# D_16L_A_16L_16R 11 0.9200606489179393
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.97385
# [1]	validation_0-auc:0.97597
# [2]	validation_0-auc:0.97839
# [3]	validation_0-auc:0.97784
# [4]	validation_0-auc:0.98021
# [5]	validation_0-auc:0.98011
# [6]	validation_0-auc:0.98017
# [7]	validation_0-auc:0.98038
# [8]	validation_0-auc:0.98026
# [9]	validation_0-auc:0.98037
# [10]	validation_0-auc:0.98017
# [11]	validation_0-auc:0.98038
# [12]	validation_0-auc:0.98036
# [13]	validation_0-auc:0.98028
# [14]	validation_0-auc:0.97996
# [15]	validation_0-auc:0.97954
# [16]	validation_0-auc:0.97977
# D_34R_A_34L_34R 11 0.9803831941552905
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.79606
# [1]	validation_0-auc:0.80500
# [2]	validation_0-auc:0.81731
# [3]	validation_0-auc:0.81708
# [4]	validation_0-auc:0.81967
# [5]	validation_0-auc:0.82462
# [6]	validation_0-auc:0.82374
# [7]	validation_0-auc:0.84109
# [8]	validation_0-auc:0.85849
# [9]	validation_0-auc:0.86619
# [10]	validation_0-auc:0.86904
# [11]	validation_0-auc:0.86497
# [12]	validation_0-auc:0.86074
# [13]	validation_0-auc:0.86429
# [14]	validation_0-auc:0.86031
# [15]	validation_0-auc:0.86469
# [16]	validation_0-auc:0.86893
# [17]	validation_0-auc:0.87421
# [18]	validation_0-auc:0.87006
# [19]	validation_0-auc:0.87201
# [20]	validation_0-auc:0.87287
# [21]	validation_0-auc:0.86958
# [22]	validation_0-auc:0.87593
# [23]	validation_0-auc:0.88316
# [24]	validation_0-auc:0.88636
# [25]	validation_0-auc:0.88953
# [26]	validation_0-auc:0.89391
# [27]	validation_0-auc:0.89498
# [28]	validation_0-auc:0.89771
# [29]	validation_0-auc:0.89716
# [30]	validation_0-auc:0.89991
# [31]	validation_0-auc:0.90238
# [32]	validation_0-auc:0.90293
# [33]	validation_0-auc:0.90284
# [34]	validation_0-auc:0.90122
# [35]	validation_0-auc:0.90218
# [36]	validation_0-auc:0.90149
# [37]	validation_0-auc:0.90167
# [38]	validation_0-auc:0.90238
# [39]	validation_0-auc:0.90260
# [40]	validation_0-auc:0.90302
# [41]	validation_0-auc:0.90562
# [42]	validation_0-auc:0.90487
# [43]	validation_0-auc:0.90484
# [44]	validation_0-auc:0.90422
# [45]	validation_0-auc:0.90351
# [46]	validation_0-auc:0.90260
# [47]	validation_0-auc:0.90318
# [48]	validation_0-auc:0.90462
# [49]	validation_0-auc:0.90462
# [50]	validation_0-auc:0.90302
# D_16L_A_16C_16L 11 0.9056222222222221
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.93982
# [1]	validation_0-auc:0.94991
# [2]	validation_0-auc:0.96588
# [3]	validation_0-auc:0.96299
# [4]	validation_0-auc:0.96390
# [5]	validation_0-auc:0.96796
# [6]	validation_0-auc:0.96588
# [7]	validation_0-auc:0.96482
# [8]	validation_0-auc:0.96574
# [9]	validation_0-auc:0.96492
# [10]	validation_0-auc:0.96154
# [11]	validation_0-auc:0.95999
# [12]	validation_0-auc:0.96313
# [13]	validation_0-auc:0.96410
# [14]	validation_0-auc:0.95975
# [15]	validation_0-auc:0.96062
# D_34R_A_34C_34R 11 0.9679567609304122
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.49873
# [1]	validation_0-auc:0.57829
# [2]	validation_0-auc:0.57870
# [3]	validation_0-auc:0.56228
# [4]	validation_0-auc:0.59484
# [5]	validation_0-auc:0.62772
# [6]	validation_0-auc:0.63405
# [7]	validation_0-auc:0.62111
# [8]	validation_0-auc:0.63136
# [9]	validation_0-auc:0.65373
# [10]	validation_0-auc:0.64427
# [11]	validation_0-auc:0.66712
# [12]	validation_0-auc:0.67968
# [13]	validation_0-auc:0.71161
# [14]	validation_0-auc:0.73272
# [15]	validation_0-auc:0.72468
# [16]	validation_0-auc:0.70203
# [17]	validation_0-auc:0.70133
# [18]	validation_0-auc:0.71620
# [19]	validation_0-auc:0.70146
# [20]	validation_0-auc:0.70753
# [21]	validation_0-auc:0.71354
# [22]	validation_0-auc:0.71728
# [23]	validation_0-auc:0.71823
# 11 0.7327215189873418
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.84513
# [1]	validation_0-auc:0.85847
# [2]	validation_0-auc:0.88122
# [3]	validation_0-auc:0.89151
# [4]	validation_0-auc:0.90734
# [5]	validation_0-auc:0.91508
# [6]	validation_0-auc:0.91338
# [7]	validation_0-auc:0.91292
# [8]	validation_0-auc:0.91473
# [9]	validation_0-auc:0.91665
# [10]	validation_0-auc:0.91507
# [11]	validation_0-auc:0.91760
# [12]	validation_0-auc:0.92282
# [13]	validation_0-auc:0.92450
# [14]	validation_0-auc:0.92130
# [15]	validation_0-auc:0.92079
# [16]	validation_0-auc:0.92179
# [17]	validation_0-auc:0.92234
# [18]	validation_0-auc:0.92180
# [19]	validation_0-auc:0.92223
# [20]	validation_0-auc:0.92139
# [21]	validation_0-auc:0.92303
# [22]	validation_0-auc:0.92440
# D_16L_A_16L_16R 12 0.9245012168534199
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.96951
# [1]	validation_0-auc:0.96980
# [2]	validation_0-auc:0.97222
# [3]	validation_0-auc:0.97358
# [4]	validation_0-auc:0.97343
# [5]	validation_0-auc:0.97397
# [6]	validation_0-auc:0.97473
# [7]	validation_0-auc:0.97382
# [8]	validation_0-auc:0.97298
# [9]	validation_0-auc:0.97455
# [10]	validation_0-auc:0.97470
# [11]	validation_0-auc:0.97569
# [12]	validation_0-auc:0.97573
# [13]	validation_0-auc:0.97556
# [14]	validation_0-auc:0.97460
# [15]	validation_0-auc:0.97482
# [16]	validation_0-auc:0.97479
# [17]	validation_0-auc:0.97500
# [18]	validation_0-auc:0.97613
# [19]	validation_0-auc:0.97576
# [20]	validation_0-auc:0.97608
# [21]	validation_0-auc:0.97568
# [22]	validation_0-auc:0.97557
# [23]	validation_0-auc:0.97541
# [24]	validation_0-auc:0.97503
# [25]	validation_0-auc:0.97573
# [26]	validation_0-auc:0.97588
# [27]	validation_0-auc:0.97525
# D_34R_A_34L_34R 12 0.9761269967379929
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.80514
# [1]	validation_0-auc:0.80826
# [2]	validation_0-auc:0.83285
# [3]	validation_0-auc:0.83214
# [4]	validation_0-auc:0.82856
# [5]	validation_0-auc:0.84814
# [6]	validation_0-auc:0.84146
# [7]	validation_0-auc:0.85084
# [8]	validation_0-auc:0.84947
# [9]	validation_0-auc:0.83629
# [10]	validation_0-auc:0.84432
# [11]	validation_0-auc:0.84381
# [12]	validation_0-auc:0.83878
# [13]	validation_0-auc:0.84538
# [14]	validation_0-auc:0.84628
# [15]	validation_0-auc:0.84281
# [16]	validation_0-auc:0.84868
# D_16L_A_16C_16L 12 0.8508398961126006
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.90910
# [1]	validation_0-auc:0.94903
# [2]	validation_0-auc:0.96343
# [3]	validation_0-auc:0.95397
# [4]	validation_0-auc:0.95657
# [5]	validation_0-auc:0.95684
# [6]	validation_0-auc:0.95729
# [7]	validation_0-auc:0.96456
# [8]	validation_0-auc:0.96330
# [9]	validation_0-auc:0.96159
# [10]	validation_0-auc:0.96025
# [11]	validation_0-auc:0.95872
# [12]	validation_0-auc:0.96204
# [13]	validation_0-auc:0.96115
# [14]	validation_0-auc:0.95890
# [15]	validation_0-auc:0.95415
# [16]	validation_0-auc:0.95854
# [17]	validation_0-auc:0.95774
# D_34R_A_34C_34R 12 0.9645549174443647
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.59687
# [1]	validation_0-auc:0.63049
# [2]	validation_0-auc:0.66764
# [3]	validation_0-auc:0.66166
# [4]	validation_0-auc:0.65896
# [5]	validation_0-auc:0.64159
# [6]	validation_0-auc:0.61567
# [7]	validation_0-auc:0.60131
# [8]	validation_0-auc:0.61205
# [9]	validation_0-auc:0.61116
# [10]	validation_0-auc:0.62491
# [11]	validation_0-auc:0.62085
# 12 0.6676358889152622

# %% [markdown]
# # Run the Bridge Pipeline

# %%
run_bridge_pipeline()
# Out:
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# ----------------------------------------------------------------------------------------------------
#
# Finished Airport: katl
#
# ----------------------------------------------------------------------------------------------------
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# ----------------------------------------------------------------------------------------------------
#
# Finished Airport: kclt
#
# ----------------------------------------------------------------------------------------------------
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# ----------------------------------------------------------------------------------------------------
#
# Finished Airport: kden
#
# ----------------------------------------------------------------------------------------------------
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# ----------------------------------------------------------------------------------------------------
#
# Finished Airport: kdfw
#
# ----------------------------------------------------------------------------------------------------
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# ----------------------------------------------------------------------------------------------------
#
# Finished Airport: kjfk
#
# ----------------------------------------------------------------------------------------------------
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# ----------------------------------------------------------------------------------------------------
#
# Finished Airport: kmem
#
# ----------------------------------------------------------------------------------------------------
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# ----------------------------------------------------------------------------------------------------
#
# Finished Airport: kmia
#
# ----------------------------------------------------------------------------------------------------
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# ----------------------------------------------------------------------------------------------------
#
# Finished Airport: kord
#
# ----------------------------------------------------------------------------------------------------
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# ----------------------------------------------------------------------------------------------------
#
# Finished Airport: kphx
#
# ----------------------------------------------------------------------------------------------------
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# ----------------------------------------------------------------------------------------------------
#
# Finished Airport: ksea
#
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# # Train Final Model

# %%
train_final_model(MCS=False)
