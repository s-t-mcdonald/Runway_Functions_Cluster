# %%
import pandas as pd
import numpy as np
import datetime

from src.const import *
from src.feature_processing_functions import *
# from src.helpers import get_file_path

from src.data_processing_pipeline import process_data
from src.submodel_pipeline import train_submodels
from src.bridge_pipeline import run_bridge_pipeline
# from src.nn_pipeline import train_final_model
# Out:
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %% [markdown]
# # Define Train, Val, and Test Timestamps
#
# ### Small sample for illustrative purposes

# %%
train_labels_df = ensure_datetime(pd.read_csv(f"open_train_labels.csv.bz2"))
train_timestamps = sorted(list(train_labels_df['timestamp'].unique()))

val_labels_df = ensure_datetime(pd.read_csv(f"open_submission_format.csv"))
val_timestamps = sorted(list(val_labels_df['timestamp'].unique()))

test_labels_df = ensure_datetime(pd.read_csv(f"evaluation_test_labels.csv"))
test_timestamps = sorted(list(test_labels_df['timestamp'].unique()))

# %% [markdown]
# # Process Raw Data

# %%
process_data(train_timestamps, val_timestamps, test_timestamps)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 process_data(train_timestamps, val_timestamps, test_timestamps)
#
# NameError: name 'train_timestamps' is not defined

# %% [markdown]
# # Train Submodels

# %%
train_submodels()
# Out:
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.93252
# [1]	validation_0-auc:0.93227
# [2]	validation_0-auc:0.93218
# [3]	validation_0-auc:0.93222
# [4]	validation_0-auc:0.93222
# [5]	validation_0-auc:0.93197
# [6]	validation_0-auc:0.93192
# [7]	validation_0-auc:0.93145
# [8]	validation_0-auc:0.93158
# [9]	validation_0-auc:0.93150
# [10]	validation_0-auc:0.92983
# 27L_departure 1 0.9325213675213676
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:nan
# [1]	validation_0-auc:nan
# [2]	validation_0-auc:nan
# [3]	validation_0-auc:nan
# [4]	validation_0-auc:nan
# [5]	validation_0-auc:nan
# [6]	validation_0-auc:nan
# [7]	validation_0-auc:nan
# [8]	validation_0-auc:nan
# [9]	validation_0-auc:nan
# 8L_departure 1 nan
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:1016: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.99070
# [1]	validation_0-auc:0.99206
# [2]	validation_0-auc:0.99246
# [3]	validation_0-auc:0.99196
# [4]	validation_0-auc:0.99312
# [5]	validation_0-auc:0.99306
# [6]	validation_0-auc:0.99353
# [7]	validation_0-auc:0.99471
# [8]	validation_0-auc:0.99461
# [9]	validation_0-auc:0.99456
# [10]	validation_0-auc:0.99438
# [11]	validation_0-auc:0.99621
# [12]	validation_0-auc:0.99667
# [13]	validation_0-auc:0.99665
# [14]	validation_0-auc:0.99698
# [15]	validation_0-auc:0.99712
# [16]	validation_0-auc:0.99745
# [17]	validation_0-auc:0.99740
# [18]	validation_0-auc:0.99730
# [19]	validation_0-auc:0.99746
# [20]	validation_0-auc:0.99756
# [21]	validation_0-auc:0.99762
# [22]	validation_0-auc:0.99749
# [23]	validation_0-auc:0.99727
# [24]	validation_0-auc:0.99733
# [25]	validation_0-auc:0.99730
# [26]	validation_0-auc:0.99717
# [27]	validation_0-auc:0.99726
# [28]	validation_0-auc:0.99728
# [29]	validation_0-auc:0.99717
# [30]	validation_0-auc:0.99704
# 9L_departure 1 0.9976227333038479
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.98716
# [1]	validation_0-auc:0.99181
# [2]	validation_0-auc:0.99330
# [3]	validation_0-auc:0.99301
# [4]	validation_0-auc:0.99306
# [5]	validation_0-auc:0.99363
# [6]	validation_0-auc:0.99385
# [7]	validation_0-auc:0.99364
# [8]	validation_0-auc:0.99317
# [9]	validation_0-auc:0.99533
# [10]	validation_0-auc:0.99539
# [11]	validation_0-auc:0.99500
# [12]	validation_0-auc:0.99520
# [13]	validation_0-auc:0.99565
# [14]	validation_0-auc:0.99571
# [15]	validation_0-auc:0.99579
# [16]	validation_0-auc:0.99543
# [17]	validation_0-auc:0.99534
# [18]	validation_0-auc:0.99576
# [19]	validation_0-auc:0.99537
# [20]	validation_0-auc:0.99551
# [21]	validation_0-auc:0.99539
# [22]	validation_0-auc:0.99539
# [23]	validation_0-auc:0.99522
# [24]	validation_0-auc:0.99527
# [25]	validation_0-auc:0.99497
# 27R_departure 1 0.9957853774780713
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.99896
# [1]	validation_0-auc:0.99896
# [2]	validation_0-auc:0.99889
# [3]	validation_0-auc:0.99868
# [4]	validation_0-auc:0.99875
# [5]	validation_0-auc:0.99875
# [6]	validation_0-auc:0.99875
# [7]	validation_0-auc:0.99868
# [8]	validation_0-auc:0.99868
# [9]	validation_0-auc:0.99840
# 10_departure 1 0.9989596337910944
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.99177
# [1]	validation_0-auc:0.99197
# [2]	validation_0-auc:0.99229
# [3]	validation_0-auc:0.99219
# [4]	validation_0-auc:0.99215
# [5]	validation_0-auc:0.99207
# [6]	validation_0-auc:0.99194
# [7]	validation_0-auc:0.99184
# [8]	validation_0-auc:0.99162
# [9]	validation_0-auc:0.99097
# [10]	validation_0-auc:0.99078
# [11]	validation_0-auc:0.99056
# 28_departure 1 0.9922903123513558
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.89938
# [1]	validation_0-auc:0.89938
# [2]	validation_0-auc:0.89938
# [3]	validation_0-auc:0.89938
# [4]	validation_0-auc:0.89938
# [5]	validation_0-auc:0.89938
# [6]	validation_0-auc:0.99453
# [7]	validation_0-auc:0.99342
# [8]	validation_0-auc:0.99217
# [9]	validation_0-auc:0.99118
# [10]	validation_0-auc:0.99279
# [11]	validation_0-auc:0.98447
# [12]	validation_0-auc:0.98398
# [13]	validation_0-auc:0.98199
# [14]	validation_0-auc:0.98174
# [15]	validation_0-auc:0.98596
# 9R_departure 1 0.9945341614906832
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.91656
# [1]	validation_0-auc:0.91656
# [2]	validation_0-auc:0.91656
# [3]	validation_0-auc:0.91656
# [4]	validation_0-auc:0.91656
# [5]	validation_0-auc:0.91636
# [6]	validation_0-auc:0.91542
# [7]	validation_0-auc:0.91335
# [8]	validation_0-auc:0.91252
# [9]	validation_0-auc:0.90931
# 26R_departure 1 0.9165630182421227
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.99213
# [1]	validation_0-auc:0.99219
# [2]	validation_0-auc:0.99472
# [3]	validation_0-auc:0.99537
# [4]	validation_0-auc:0.99544
# [5]	validation_0-auc:0.99530
# [6]	validation_0-auc:0.99685
# [7]	validation_0-auc:0.99780
# [8]	validation_0-auc:0.99784
# [9]	validation_0-auc:0.99774
# [10]	validation_0-auc:0.99770
# [11]	validation_0-auc:0.99762
# [12]	validation_0-auc:0.99781
# [13]	validation_0-auc:0.99783
# [14]	validation_0-auc:0.99789
# [15]	validation_0-auc:0.99789
# [16]	validation_0-auc:0.99792
# [17]	validation_0-auc:0.99792
# [18]	validation_0-auc:0.99792
# [19]	validation_0-auc:0.99820
# [20]	validation_0-auc:0.99813
# [21]	validation_0-auc:0.99806
# [22]	validation_0-auc:0.99795
# [23]	validation_0-auc:0.99799
# [24]	validation_0-auc:0.99790
# [25]	validation_0-auc:0.99789
# [26]	validation_0-auc:0.99782
# [27]	validation_0-auc:0.99777
# [28]	validation_0-auc:0.99775
# [29]	validation_0-auc:0.99778
# 8R_departure 1 0.9982027662366062
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.99328
# [1]	validation_0-auc:0.99512
# [2]	validation_0-auc:0.99500
# [3]	validation_0-auc:0.99485
# [4]	validation_0-auc:0.99516
# [5]	validation_0-auc:0.99512
# [6]	validation_0-auc:0.99654
# [7]	validation_0-auc:0.99671
# [8]	validation_0-auc:0.99742
# [9]	validation_0-auc:0.99732
# [10]	validation_0-auc:0.99725
# [11]	validation_0-auc:0.99723
# [12]	validation_0-auc:0.99717
# [13]	validation_0-auc:0.99718
# [14]	validation_0-auc:0.99724
# [15]	validation_0-auc:0.99744
# [16]	validation_0-auc:0.99763
# [17]	validation_0-auc:0.99803
# [18]	validation_0-auc:0.99804
# [19]	validation_0-auc:0.99811
# [20]	validation_0-auc:0.99816
# [21]	validation_0-auc:0.99830
# [22]	validation_0-auc:0.99838
# [23]	validation_0-auc:0.99839
# [24]	validation_0-auc:0.99833
# [25]	validation_0-auc:0.99850
# [26]	validation_0-auc:0.99852
# [27]	validation_0-auc:0.99848
# [28]	validation_0-auc:0.99840
# [29]	validation_0-auc:0.99836
# [30]	validation_0-auc:0.99838
# [31]	validation_0-auc:0.99826
# [32]	validation_0-auc:0.99816
# [33]	validation_0-auc:0.99817
# [34]	validation_0-auc:0.99821
# [35]	validation_0-auc:0.99829
# [36]	validation_0-auc:0.99818
# 26L_departure 1 0.9985145888594165
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.99028
# [1]	validation_0-auc:0.99034
# [2]	validation_0-auc:0.99085
# [3]	validation_0-auc:0.99063
# [4]	validation_0-auc:0.99032
# [5]	validation_0-auc:0.99042
# [6]	validation_0-auc:0.99229
# [7]	validation_0-auc:0.99228
# [8]	validation_0-auc:0.99424
# [9]	validation_0-auc:0.99475
# [10]	validation_0-auc:0.99543
# [11]	validation_0-auc:0.99579
# [12]	validation_0-auc:0.99551
# [13]	validation_0-auc:0.99530
# [14]	validation_0-auc:0.99475
# [15]	validation_0-auc:0.99445
# [16]	validation_0-auc:0.99421
# [17]	validation_0-auc:0.99409
# [18]	validation_0-auc:0.99390
# [19]	validation_0-auc:0.99415
# [20]	validation_0-auc:0.99391
# [21]	validation_0-auc:0.99342
# 27L_arrival 1 0.9957858499525166
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.99099
# [1]	validation_0-auc:0.99268
# [2]	validation_0-auc:0.99334
# [3]	validation_0-auc:0.99327
# [4]	validation_0-auc:0.99306
# [5]	validation_0-auc:0.99420
# [6]	validation_0-auc:0.99500
# [7]	validation_0-auc:0.99491
# [8]	validation_0-auc:0.99524
# [9]	validation_0-auc:0.99516
# [10]	validation_0-auc:0.99506
# [11]	validation_0-auc:0.99499
# [12]	validation_0-auc:0.99481
# [13]	validation_0-auc:0.99606
# [14]	validation_0-auc:0.99638
# [15]	validation_0-auc:0.99669
# [16]	validation_0-auc:0.99671
# [17]	validation_0-auc:0.99663
# [18]	validation_0-auc:0.99638
# [19]	validation_0-auc:0.99657
# [20]	validation_0-auc:0.99656
# [21]	validation_0-auc:0.99659
# [22]	validation_0-auc:0.99665
# [23]	validation_0-auc:0.99648
# [24]	validation_0-auc:0.99650
# [25]	validation_0-auc:0.99662
# 8L_arrival 1 0.9967144394720444
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.94371
# [1]	validation_0-auc:0.94367
# [2]	validation_0-auc:0.94374
# [3]	validation_0-auc:0.94374
# [4]	validation_0-auc:0.94374
# [5]	validation_0-auc:0.94353
# [6]	validation_0-auc:0.94374
# [7]	validation_0-auc:0.94283
# [8]	validation_0-auc:0.94220
# [9]	validation_0-auc:0.94213
# [10]	validation_0-auc:0.94213
# [11]	validation_0-auc:0.94171
# [12]	validation_0-auc:0.94045
# 9L_arrival 1 0.943742985409652
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.98430
# [1]	validation_0-auc:0.98421
# [2]	validation_0-auc:0.98423
# [3]	validation_0-auc:0.98486
# [4]	validation_0-auc:0.98442
# [5]	validation_0-auc:0.98441
# [6]	validation_0-auc:0.98432
# [7]	validation_0-auc:0.98389
# [8]	validation_0-auc:0.98383
# [9]	validation_0-auc:0.98376
# [10]	validation_0-auc:0.98372
# [11]	validation_0-auc:0.98369
# [12]	validation_0-auc:0.99388
# [13]	validation_0-auc:0.99345
# [14]	validation_0-auc:0.98979
# [15]	validation_0-auc:0.98796
# [16]	validation_0-auc:0.98704
# [17]	validation_0-auc:0.98694
# [18]	validation_0-auc:0.98690
# [19]	validation_0-auc:0.98758
# [20]	validation_0-auc:0.99347
# [21]	validation_0-auc:0.99462
# [22]	validation_0-auc:0.99397
# [23]	validation_0-auc:0.99361
# [24]	validation_0-auc:0.99311
# [25]	validation_0-auc:0.99307
# [26]	validation_0-auc:0.99304
# [27]	validation_0-auc:0.99343
# [28]	validation_0-auc:0.99322
# [29]	validation_0-auc:0.99411
# [30]	validation_0-auc:0.99361
# 27R_arrival 1 0.9946167097329888
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.99086
# [1]	validation_0-auc:0.99223
# [2]	validation_0-auc:0.99253
# [3]	validation_0-auc:0.99361
# [4]	validation_0-auc:0.99366
# [5]	validation_0-auc:0.99355
# [6]	validation_0-auc:0.99352
# [7]	validation_0-auc:0.99533
# [8]	validation_0-auc:0.99537
# [9]	validation_0-auc:0.99535
# [10]	validation_0-auc:0.99568
# [11]	validation_0-auc:0.99549
# [12]	validation_0-auc:0.99582
# [13]	validation_0-auc:0.99535
# [14]	validation_0-auc:0.99596
# [15]	validation_0-auc:0.99588
# [16]	validation_0-auc:0.99675
# [17]	validation_0-auc:0.99673
# [18]	validation_0-auc:0.99656
# [19]	validation_0-auc:0.99662
# [20]	validation_0-auc:0.99684
# [21]	validation_0-auc:0.99684
# [22]	validation_0-auc:0.99694
# [23]	validation_0-auc:0.99694
# [24]	validation_0-auc:0.99692
# [25]	validation_0-auc:0.99686
# [26]	validation_0-auc:0.99680
# [27]	validation_0-auc:0.99687
# [28]	validation_0-auc:0.99693
# [29]	validation_0-auc:0.99679
# [30]	validation_0-auc:0.99675
# [31]	validation_0-auc:0.99677
# 10_arrival 1 0.996939227841065
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.98584
# [1]	validation_0-auc:0.98709
# [2]	validation_0-auc:0.98679
# [3]	validation_0-auc:0.98679
# [4]	validation_0-auc:0.98713
# [5]	validation_0-auc:0.98670
# [6]	validation_0-auc:0.98814
# [7]	validation_0-auc:0.98793
# [8]	validation_0-auc:0.98844
# [9]	validation_0-auc:0.98816
# [10]	validation_0-auc:0.98776
# [11]	validation_0-auc:0.98794
# [12]	validation_0-auc:0.98813
# [13]	validation_0-auc:0.98768
# [14]	validation_0-auc:0.98840
# [15]	validation_0-auc:0.98997
# [16]	validation_0-auc:0.98996
# [17]	validation_0-auc:0.99097
# [18]	validation_0-auc:0.99178
# [19]	validation_0-auc:0.99202
# [20]	validation_0-auc:0.99225
# [21]	validation_0-auc:0.99259
# [22]	validation_0-auc:0.99214
# [23]	validation_0-auc:0.99235
# [24]	validation_0-auc:0.99250
# [25]	validation_0-auc:0.99255
# [26]	validation_0-auc:0.99252
# [27]	validation_0-auc:0.99250
# [28]	validation_0-auc:0.99268
# [29]	validation_0-auc:0.99299
# [30]	validation_0-auc:0.99311
# [31]	validation_0-auc:0.99304
# [32]	validation_0-auc:0.99314
# [33]	validation_0-auc:0.99322
# [34]	validation_0-auc:0.99338
# [35]	validation_0-auc:0.99333
# [36]	validation_0-auc:0.99333
# [37]	validation_0-auc:0.99338
# [38]	validation_0-auc:0.99356
# [39]	validation_0-auc:0.99369
# [40]	validation_0-auc:0.99369
# [41]	validation_0-auc:0.99358
# [42]	validation_0-auc:0.99342
# [43]	validation_0-auc:0.99343
# [44]	validation_0-auc:0.99330
# [45]	validation_0-auc:0.99335
# [46]	validation_0-auc:0.99314
# [47]	validation_0-auc:0.99306
# [48]	validation_0-auc:0.99309
# [49]	validation_0-auc:0.99309
# 28_arrival 1 0.9936948873760679
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.99120
# [1]	validation_0-auc:0.99105
# [2]	validation_0-auc:0.99262
# [3]	validation_0-auc:0.99442
# [4]	validation_0-auc:0.99464
# [5]	validation_0-auc:0.99470
# [6]	validation_0-auc:0.99548
# [7]	validation_0-auc:0.99542
# [8]	validation_0-auc:0.99518
# [9]	validation_0-auc:0.99518
# [10]	validation_0-auc:0.99484
# [11]	validation_0-auc:0.99512
# [12]	validation_0-auc:0.99681
# [13]	validation_0-auc:0.99677
# [14]	validation_0-auc:0.99665
# [15]	validation_0-auc:0.99683
# [16]	validation_0-auc:0.99670
# [17]	validation_0-auc:0.99637
# [18]	validation_0-auc:0.99654
# [19]	validation_0-auc:0.99624
# [20]	validation_0-auc:0.99593
# [21]	validation_0-auc:0.99559
# [22]	validation_0-auc:0.99635
# [23]	validation_0-auc:0.99672
# [24]	validation_0-auc:0.99679
# 9R_arrival 1 0.9968280100197983
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.98988
# [1]	validation_0-auc:0.99203
# [2]	validation_0-auc:0.99173
# [3]	validation_0-auc:0.99074
# [4]	validation_0-auc:0.99131
# [5]	validation_0-auc:0.99181
# [6]	validation_0-auc:0.99188
# [7]	validation_0-auc:0.99237
# [8]	validation_0-auc:0.99276
# [9]	validation_0-auc:0.99250
# [10]	validation_0-auc:0.99330
# [11]	validation_0-auc:0.99282
# [12]	validation_0-auc:0.99475
# [13]	validation_0-auc:0.99430
# [14]	validation_0-auc:0.99368
# [15]	validation_0-auc:0.99389
# [16]	validation_0-auc:0.99462
# [17]	validation_0-auc:0.99443
# [18]	validation_0-auc:0.99406
# [19]	validation_0-auc:0.99480
# [20]	validation_0-auc:0.99495
# [21]	validation_0-auc:0.99478
# [22]	validation_0-auc:0.99464
# [23]	validation_0-auc:0.99432
# [24]	validation_0-auc:0.99448
# [25]	validation_0-auc:0.99432
# [26]	validation_0-auc:0.99403
# [27]	validation_0-auc:0.99407
# [28]	validation_0-auc:0.99470
# [29]	validation_0-auc:0.99448
# [30]	validation_0-auc:0.99455
# 26R_arrival 1 0.9949521041198549
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.90824
# [1]	validation_0-auc:0.90852
# [2]	validation_0-auc:0.90852
# [3]	validation_0-auc:0.90852
# [4]	validation_0-auc:0.90761
# [5]	validation_0-auc:0.90790
# [6]	validation_0-auc:0.94550
# [7]	validation_0-auc:0.94550
# [8]	validation_0-auc:0.94510
# [9]	validation_0-auc:0.94254
# [10]	validation_0-auc:0.94061
# [11]	validation_0-auc:0.94066
# [12]	validation_0-auc:0.93492
# [13]	validation_0-auc:0.93390
# [14]	validation_0-auc:0.96535
# [15]	validation_0-auc:0.97190
# [16]	validation_0-auc:0.95631
# [17]	validation_0-auc:0.95529
# [18]	validation_0-auc:0.96996
# [19]	validation_0-auc:0.96609
# [20]	validation_0-auc:0.98487
# [21]	validation_0-auc:0.98179
# [22]	validation_0-auc:0.98691
# [23]	validation_0-auc:0.98350
# [24]	validation_0-auc:0.98191
# [25]	validation_0-auc:0.98191
# [26]	validation_0-auc:0.98191
# [27]	validation_0-auc:0.98043
# [28]	validation_0-auc:0.97906
# [29]	validation_0-auc:0.97850
# [30]	validation_0-auc:0.97622
# [31]	validation_0-auc:0.97429
# [32]	validation_0-auc:0.97292
# 8R_arrival 1 0.9869154625099557
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.97951
# [1]	validation_0-auc:0.97965
# [2]	validation_0-auc:0.97975
# [3]	validation_0-auc:0.98008
# [4]	validation_0-auc:0.98005
# [5]	validation_0-auc:0.97992
# [6]	validation_0-auc:0.98015
# [7]	validation_0-auc:0.98010
# [8]	validation_0-auc:0.97997
# [9]	validation_0-auc:0.98900
# [10]	validation_0-auc:0.98910
# [11]	validation_0-auc:0.98872
# [12]	validation_0-auc:0.99398
# [13]	validation_0-auc:0.99366
# [14]	validation_0-auc:0.99308
# [15]	validation_0-auc:0.99171
# [16]	validation_0-auc:0.99138
# [17]	validation_0-auc:0.99572
# [18]	validation_0-auc:0.99513
# [19]	validation_0-auc:0.99484
# [20]	validation_0-auc:0.99427
# [21]	validation_0-auc:0.99335
# [22]	validation_0-auc:0.99387
# [23]	validation_0-auc:0.99350
# [24]	validation_0-auc:0.99265
# [25]	validation_0-auc:0.99252
# [26]	validation_0-auc:0.99235
# [27]	validation_0-auc:0.99157
# 26L_arrival 1 0.995725430572518
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.98375
# [1]	validation_0-auc:0.98697
# [2]	validation_0-auc:0.98770
# [3]	validation_0-auc:0.98824
# [4]	validation_0-auc:0.98813
# [5]	validation_0-auc:0.98871
# [6]	validation_0-auc:0.98832
# [7]	validation_0-auc:0.98801
# [8]	validation_0-auc:0.98787
# [9]	validation_0-auc:0.98720
# [10]	validation_0-auc:0.98804
# [11]	validation_0-auc:0.98941
# [12]	validation_0-auc:0.98908
# [13]	validation_0-auc:0.98965
# [14]	validation_0-auc:0.98969
# [15]	validation_0-auc:0.98999
# [16]	validation_0-auc:0.98963
# [17]	validation_0-auc:0.98930
# [18]	validation_0-auc:0.98900
# [19]	validation_0-auc:0.98875
# [20]	validation_0-auc:0.98842
# [21]	validation_0-auc:0.98840
# [22]	validation_0-auc:0.98857
# [23]	validation_0-auc:0.98809
# [24]	validation_0-auc:0.98833
# [25]	validation_0-auc:0.98839
# D_26L_27R_A_26R_27L_28 1 0.9899867957746478
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.98934
# [1]	validation_0-auc:0.98964
# [2]	validation_0-auc:0.99376
# [3]	validation_0-auc:0.99579
# [4]	validation_0-auc:0.99515
# [5]	validation_0-auc:0.99521
# [6]	validation_0-auc:0.99497
# [7]	validation_0-auc:0.99513
# [8]	validation_0-auc:0.99600
# [9]	validation_0-auc:0.99622
# [10]	validation_0-auc:0.99602
# [11]	validation_0-auc:0.99568
# [12]	validation_0-auc:0.99551
# [13]	validation_0-auc:0.99544
# [14]	validation_0-auc:0.99534
# [15]	validation_0-auc:0.99487
# [16]	validation_0-auc:0.99472
# [17]	validation_0-auc:0.99453
# [18]	validation_0-auc:0.99435
# [19]	validation_0-auc:0.99423
# D_8R_9L_A_10_8L_9R 1 0.9962185162832982
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.95863
# [1]	validation_0-auc:0.97526
# [2]	validation_0-auc:0.97975
# [3]	validation_0-auc:0.97620
# [4]	validation_0-auc:0.97749
# [5]	validation_0-auc:0.97669
# [6]	validation_0-auc:0.97904
# [7]	validation_0-auc:0.97931
# [8]	validation_0-auc:0.97911
# [9]	validation_0-auc:0.97893
# [10]	validation_0-auc:0.97856
# [11]	validation_0-auc:0.97888
# [12]	validation_0-auc:0.97943
# other 1 0.979747386759582
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:1.00000
# [1]	validation_0-auc:1.00000
# [2]	validation_0-auc:1.00000
# [3]	validation_0-auc:1.00000
# [4]	validation_0-auc:1.00000
# [5]	validation_0-auc:1.00000
# [6]	validation_0-auc:1.00000
# [7]	validation_0-auc:1.00000
# [8]	validation_0-auc:1.00000
# [9]	validation_0-auc:1.00000
# D_26L_27R_28_A_26R_27L_28 1 1.0
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.83313
# [1]	validation_0-auc:0.83313
# [2]	validation_0-auc:0.83313
# [3]	validation_0-auc:0.83313
# [4]	validation_0-auc:0.83313
# [5]	validation_0-auc:0.83271
# [6]	validation_0-auc:0.93578
# [7]	validation_0-auc:0.93578
# [8]	validation_0-auc:0.93550
# [9]	validation_0-auc:0.93536
# [10]	validation_0-auc:0.93473
# [11]	validation_0-auc:0.93473
# [12]	validation_0-auc:0.92669
# [13]	validation_0-auc:0.92724
# [14]	validation_0-auc:0.96088
# [15]	validation_0-auc:0.96234
# [16]	validation_0-auc:0.98446
# [17]	validation_0-auc:0.98335
# [18]	validation_0-auc:0.98183
# [19]	validation_0-auc:0.98266
# [20]	validation_0-auc:0.98252
# [21]	validation_0-auc:0.98113
# [22]	validation_0-auc:0.98405
# [23]	validation_0-auc:0.98169
# [24]	validation_0-auc:0.98016
# [25]	validation_0-auc:0.98113
# [26]	validation_0-auc:0.98446
# D_26L_27R_A_26L_27L_28 1 0.9844638646136774
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.75000
# [1]	validation_0-auc:0.75000
# [2]	validation_0-auc:0.75000
# [3]	validation_0-auc:0.74876
# [4]	validation_0-auc:0.74876
# [5]	validation_0-auc:0.74876
# [6]	validation_0-auc:0.74876
# [7]	validation_0-auc:0.74691
# [8]	validation_0-auc:0.74536
# [9]	validation_0-auc:0.74536
# [10]	validation_0-auc:0.73701
# D_8R_9R_A_10_8L_9R 1 0.75
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.99983
# [1]	validation_0-auc:0.99977
# [2]	validation_0-auc:0.99977
# [3]	validation_0-auc:0.99957
# [4]	validation_0-auc:0.99980
# [5]	validation_0-auc:0.99967
# [6]	validation_0-auc:0.99967
# [7]	validation_0-auc:0.99947
# [8]	validation_0-auc:0.99953
# [9]	validation_0-auc:0.99933
# D_26L_28_A_26L_28 1 0.9998336549337946
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:nan
# [1]	validation_0-auc:nan
# [2]	validation_0-auc:nan
# [3]	validation_0-auc:nan
# [4]	validation_0-auc:nan
# [5]	validation_0-auc:nan
# [6]	validation_0-auc:nan
# [7]	validation_0-auc:nan
# [8]	validation_0-auc:nan
# [9]	validation_0-auc:nan
# D_26R_28_A_26R_28 1 nan
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:1016: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.87407
# [1]	validation_0-auc:0.87407
# [2]	validation_0-auc:0.87407
# [3]	validation_0-auc:0.87407
# [4]	validation_0-auc:0.87407
# [5]	validation_0-auc:0.87407
# [6]	validation_0-auc:0.87407
# [7]	validation_0-auc:0.86662
# [8]	validation_0-auc:0.86430
# [9]	validation_0-auc:0.83778
# D_26L_27R_A_26R_27L 1 0.8740694789081885
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.81172
# [1]	validation_0-auc:0.81164
# [2]	validation_0-auc:0.93306
# [3]	validation_0-auc:0.93368
# [4]	validation_0-auc:0.93384
# [5]	validation_0-auc:0.93259
# [6]	validation_0-auc:0.93368
# [7]	validation_0-auc:0.93337
# [8]	validation_0-auc:0.93251
# [9]	validation_0-auc:0.93142
# [10]	validation_0-auc:0.92955
# [11]	validation_0-auc:0.92908
# [12]	validation_0-auc:0.92768
# [13]	validation_0-auc:0.92682
# [14]	validation_0-auc:0.92394
# D_26L_27L_A_26R_27L_28 1 0.9338372817955112
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-mlogloss:0.64166
# [1]	validation_0-mlogloss:0.53260
# [2]	validation_0-mlogloss:0.45628
# [3]	validation_0-mlogloss:0.40351
# [4]	validation_0-mlogloss:0.36585
# [5]	validation_0-mlogloss:0.33796
# [6]	validation_0-mlogloss:0.31618
# [7]	validation_0-mlogloss:0.30342
# [8]	validation_0-mlogloss:0.29340
# [9]	validation_0-mlogloss:0.28712
# [10]	validation_0-mlogloss:0.28281
# [11]	validation_0-mlogloss:0.27922
# [12]	validation_0-mlogloss:0.27707
# [13]	validation_0-mlogloss:0.27619
# [14]	validation_0-mlogloss:0.27788
# [15]	validation_0-mlogloss:0.27800
# [16]	validation_0-mlogloss:0.27670
# [17]	validation_0-mlogloss:0.27613
# [18]	validation_0-mlogloss:0.27705
# [19]	validation_0-mlogloss:0.27653
# [20]	validation_0-mlogloss:0.27630
# [21]	validation_0-mlogloss:0.27719
# [22]	validation_0-mlogloss:0.27769
# [23]	validation_0-mlogloss:0.27779
# [24]	validation_0-mlogloss:0.27880
# [25]	validation_0-mlogloss:0.27914
# [26]	validation_0-mlogloss:0.28138
# [27]	validation_0-mlogloss:0.28269
# 1 0.9358024691358025
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.71492
# [1]	validation_0-auc:0.71813
# [2]	validation_0-auc:0.72194
# [3]	validation_0-auc:0.72565
# [4]	validation_0-auc:0.71915
# [5]	validation_0-auc:0.72329
# [6]	validation_0-auc:0.74106
# [7]	validation_0-auc:0.74386
# [8]	validation_0-auc:0.76073
# [9]	validation_0-auc:0.76955
# [10]	validation_0-auc:0.76092
# [11]	validation_0-auc:0.76597
# [12]	validation_0-auc:0.77239
# [13]	validation_0-auc:0.77395
# [14]	validation_0-auc:0.77901
# [15]	validation_0-auc:0.77069
# [16]	validation_0-auc:0.76956
# [17]	validation_0-auc:0.76855
# [18]	validation_0-auc:0.77666
# [19]	validation_0-auc:0.77570
# [20]	validation_0-auc:0.77392
# [21]	validation_0-auc:0.76887
# [22]	validation_0-auc:0.76571
# [23]	validation_0-auc:0.76434
# 1 0.7790082809538061
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# ...
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.88494
# [1]	validation_0-auc:0.93242
# [2]	validation_0-auc:0.92573
# [3]	validation_0-auc:0.92418
# [4]	validation_0-auc:0.93259
# [5]	validation_0-auc:0.93254
# [6]	validation_0-auc:0.93203
# [7]	validation_0-auc:0.93780
# [8]	validation_0-auc:0.93806
# [9]	validation_0-auc:0.94109
# [10]	validation_0-auc:0.94134
# [11]	validation_0-auc:0.94007
# [12]	validation_0-auc:0.93988
# [13]	validation_0-auc:0.93761
# [14]	validation_0-auc:0.94148
# [15]	validation_0-auc:0.94103
# [16]	validation_0-auc:0.94148
# [17]	validation_0-auc:0.94324
# [18]	validation_0-auc:0.94416
# [19]	validation_0-auc:0.94510
# [20]	validation_0-auc:0.94442
# [21]	validation_0-auc:0.94563
# [22]	validation_0-auc:0.94522
# [23]	validation_0-auc:0.94629
# [24]	validation_0-auc:0.94608
# [25]	validation_0-auc:0.94444
# [26]	validation_0-auc:0.94373
# [27]	validation_0-auc:0.94608
# [28]	validation_0-auc:0.94557
# [29]	validation_0-auc:0.94381
# [30]	validation_0-auc:0.94471
# [31]	validation_0-auc:0.94416
# [32]	validation_0-auc:0.94334
# D_25_34L_8_A_34R_35L_35R 3 0.94629271059477
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.93085
# [1]	validation_0-auc:0.93462
# [2]	validation_0-auc:0.92695
# [3]	validation_0-auc:0.94367
# [4]	validation_0-auc:0.96245
# [5]	validation_0-auc:0.96152
# [6]	validation_0-auc:0.95986
# [7]	validation_0-auc:0.95770
# [8]	validation_0-auc:0.96192
# [9]	validation_0-auc:0.95936
# [10]	validation_0-auc:0.95770
# [11]	validation_0-auc:0.95516
# [12]	validation_0-auc:0.95730
# [13]	validation_0-auc:0.95457
# D_17L_25_8_A_16L_16R_17R 3 0.9624526691326141
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.92546
# [1]	validation_0-auc:0.92380
# [2]	validation_0-auc:0.91803
# [3]	validation_0-auc:0.92254
# [4]	validation_0-auc:0.92668
# [5]	validation_0-auc:0.92627
# [6]	validation_0-auc:0.92041
# [7]	validation_0-auc:0.92355
# [8]	validation_0-auc:0.93407
# [9]	validation_0-auc:0.93563
# [10]	validation_0-auc:0.94193
# [11]	validation_0-auc:0.94015
# [12]	validation_0-auc:0.94033
# [13]	validation_0-auc:0.94469
# [14]	validation_0-auc:0.94723
# [15]	validation_0-auc:0.95055
# [16]	validation_0-auc:0.95022
# [17]	validation_0-auc:0.94969
# [18]	validation_0-auc:0.95225
# [19]	validation_0-auc:0.95273
# [20]	validation_0-auc:0.94870
# [21]	validation_0-auc:0.95101
# [22]	validation_0-auc:0.95048
# [23]	validation_0-auc:0.94903
# [24]	validation_0-auc:0.94949
# [25]	validation_0-auc:0.94774
# [26]	validation_0-auc:0.94675
# [27]	validation_0-auc:0.94515
# [28]	validation_0-auc:0.94497
# [29]	validation_0-auc:0.94401
# D_25_34L_A_34R_35L_35R 3 0.9527349299776741
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.88911
# [1]	validation_0-auc:0.91700
# [2]	validation_0-auc:0.90960
# [3]	validation_0-auc:0.91323
# [4]	validation_0-auc:0.91051
# [5]	validation_0-auc:0.91314
# [6]	validation_0-auc:0.91171
# [7]	validation_0-auc:0.91185
# [8]	validation_0-auc:0.91215
# [9]	validation_0-auc:0.91080
# [10]	validation_0-auc:0.91010
# [11]	validation_0-auc:0.92282
# [12]	validation_0-auc:0.93507
# [13]	validation_0-auc:0.93972
# [14]	validation_0-auc:0.93781
# [15]	validation_0-auc:0.93685
# [16]	validation_0-auc:0.93706
# [17]	validation_0-auc:0.93504
# [18]	validation_0-auc:0.93737
# [19]	validation_0-auc:0.93461
# [20]	validation_0-auc:0.93592
# [21]	validation_0-auc:0.93564
# [22]	validation_0-auc:0.93641
# D_25_34L_8_A_35L_35R 3 0.9397194400182107
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.87913
# [1]	validation_0-auc:0.95264
# [2]	validation_0-auc:0.95183
# [3]	validation_0-auc:0.94271
# [4]	validation_0-auc:0.94662
# [5]	validation_0-auc:0.95239
# [6]	validation_0-auc:0.94883
# [7]	validation_0-auc:0.95473
# [8]	validation_0-auc:0.95676
# [9]	validation_0-auc:0.95948
# [10]	validation_0-auc:0.95919
# [11]	validation_0-auc:0.95845
# [12]	validation_0-auc:0.95900
# [13]	validation_0-auc:0.96052
# [14]	validation_0-auc:0.95849
# [15]	validation_0-auc:0.95889
# [16]	validation_0-auc:0.96059
# [17]	validation_0-auc:0.96103
# [18]	validation_0-auc:0.96052
# [19]	validation_0-auc:0.95875
# [20]	validation_0-auc:0.95912
# [21]	validation_0-auc:0.95794
# [22]	validation_0-auc:0.95978
# [23]	validation_0-auc:0.95963
# [24]	validation_0-auc:0.96022
# [25]	validation_0-auc:0.96074
# [26]	validation_0-auc:0.96114
# [27]	validation_0-auc:0.96033
# [28]	validation_0-auc:0.96030
# [29]	validation_0-auc:0.96129
# [30]	validation_0-auc:0.96118
# [31]	validation_0-auc:0.96063
# [32]	validation_0-auc:0.95908
# [33]	validation_0-auc:0.95882
# [34]	validation_0-auc:0.95867
# [35]	validation_0-auc:0.95875
# [36]	validation_0-auc:0.95712
# [37]	validation_0-auc:0.95709
# [38]	validation_0-auc:0.95712
# D_17L_8_A_16R_17R 3 0.9612903225806451
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.87919
# [1]	validation_0-auc:0.88350
# [2]	validation_0-auc:0.91017
# [3]	validation_0-auc:0.90521
# [4]	validation_0-auc:0.90913
# [5]	validation_0-auc:0.90897
# [6]	validation_0-auc:0.90540
# [7]	validation_0-auc:0.90961
# [8]	validation_0-auc:0.90963
# [9]	validation_0-auc:0.91032
# [10]	validation_0-auc:0.90965
# [11]	validation_0-auc:0.91138
# [12]	validation_0-auc:0.91280
# [13]	validation_0-auc:0.91261
# [14]	validation_0-auc:0.91625
# [15]	validation_0-auc:0.91441
# [16]	validation_0-auc:0.91086
# [17]	validation_0-auc:0.91081
# [18]	validation_0-auc:0.91027
# [19]	validation_0-auc:0.91055
# [20]	validation_0-auc:0.90994
# [21]	validation_0-auc:0.91614
# [22]	validation_0-auc:0.91110
# [23]	validation_0-auc:0.91067
# [24]	validation_0-auc:0.92261
# [25]	validation_0-auc:0.92853
# [26]	validation_0-auc:0.92668
# [27]	validation_0-auc:0.93184
# [28]	validation_0-auc:0.93392
# [29]	validation_0-auc:0.93132
# [30]	validation_0-auc:0.93108
# [31]	validation_0-auc:0.93401
# [32]	validation_0-auc:0.93151
# [33]	validation_0-auc:0.93146
# [34]	validation_0-auc:0.93293
# [35]	validation_0-auc:0.93553
# [36]	validation_0-auc:0.93761
# [37]	validation_0-auc:0.93993
# [38]	validation_0-auc:0.93799
# [39]	validation_0-auc:0.93789
# [40]	validation_0-auc:0.93846
# [41]	validation_0-auc:0.94002
# [42]	validation_0-auc:0.93865
# [43]	validation_0-auc:0.94031
# [44]	validation_0-auc:0.93903
# [45]	validation_0-auc:0.93605
# [46]	validation_0-auc:0.93851
# [47]	validation_0-auc:0.93988
# [48]	validation_0-auc:0.93964
# [49]	validation_0-auc:0.93969
# [50]	validation_0-auc:0.93837
# [51]	validation_0-auc:0.93780
# [52]	validation_0-auc:0.93832
# D_17L_25_8_A_16R_17R 3 0.9403055673809185
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.77224
# [1]	validation_0-auc:0.78412
# [2]	validation_0-auc:0.78768
# [3]	validation_0-auc:0.77252
# [4]	validation_0-auc:0.77142
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 train_submodels()
#
# File ~/Desktop/Runway_Functions_Submission/training_src/src/submodel_pipeline.py:85, in train_submodels()
#      83 preparator_description['model_name'] = model_name
#      84 model = XGBClassifier(objective ='binary:logistic', eval_metric = "auc", verbosity = 0)
# ---> 85 model.fit(binary_config_preparator.train_features_df,binary_config_preparator.y_train, early_stopping_rounds=10, eval_set=[(binary_config_preparator.val_features_df,binary_config_preparator.y_val)])
#      86 predictions = model.predict_proba(binary_config_preparator.val_features_df)
#      87 fpr,tpr,thresholds = roc_curve(binary_config_preparator.val_labels,predictions[:,1])
#
# File ~/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/core.py:506, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#     504 for k, arg in zip(sig.parameters, args):
#     505     kwargs[k] = arg
# --> 506 return f(**kwargs)
#
# File ~/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/sklearn.py:1250, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1230 model, feval, params = self._configure_fit(xgb_model, eval_metric, params)
#    1231 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1232     missing=self.missing,
#    1233     X=X,
#    (...)
#    1247     label_transform=label_transform,
#    1248 )
# -> 1250 self._Booster = train(
#    1251     params,
#    1252     train_dmatrix,
#    1253     self.get_num_boosting_rounds(),
#    1254     evals=evals,
#    1255     early_stopping_rounds=early_stopping_rounds,
#    1256     evals_result=evals_result,
#    1257     obj=obj,
#    1258     feval=feval,
#    1259     verbose_eval=verbose,
#    1260     xgb_model=model,
#    1261     callbacks=callbacks,
#    1262 )
#    1264 if not callable(self.objective):
#    1265     self.objective = params["objective"]
#
# File ~/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/training.py:188, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks)
#     115 def train(params, dtrain, num_boost_round=10, evals=(), obj=None, feval=None,
#     116           maximize=None, early_stopping_rounds=None, evals_result=None,
#     117           verbose_eval=True, xgb_model=None, callbacks=None):
#     118     # pylint: disable=too-many-statements,too-many-branches, attribute-defined-outside-init
#     119     """Train a booster with given parameters.
#     120
#     121     Parameters
#    (...)
#     186     Booster : a trained booster model
#     187     """
# --> 188     bst = _train_internal(params, dtrain,
#     189                           num_boost_round=num_boost_round,
#     190                           evals=evals,
#     191                           obj=obj, feval=feval,
#     192                           xgb_model=xgb_model, callbacks=callbacks,
#     193                           verbose_eval=verbose_eval,
#     194                           evals_result=evals_result,
#     195                           maximize=maximize,
#     196                           early_stopping_rounds=early_stopping_rounds)
#     197     return bst
#
# File ~/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/training.py:81, in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks, evals_result, maximize, verbose_eval, early_stopping_rounds)
#      79 if callbacks.before_iteration(bst, i, dtrain, evals):
#      80     break
# ---> 81 bst.update(dtrain, i, obj)
#      82 if callbacks.after_iteration(bst, i, dtrain, evals):
#      83     break
#
# File ~/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/core.py:1680, in Booster.update(self, dtrain, iteration, fobj)
#    1677 self._validate_features(dtrain)
#    1679 if fobj is None:
# -> 1680     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1681                                             ctypes.c_int(iteration),
#    1682                                             dtrain.handle))
#    1683 else:
#    1684     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %% [markdown]
# # Run the Bridge Pipeline

# %%
run_bridge_pipeline()
# Out:
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# ----------------------------------------------------------------------------------------------------
#
# Finished Airport: katl
#
# ----------------------------------------------------------------------------------------------------
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# ----------------------------------------------------------------------------------------------------
#
# Finished Airport: kclt
#
# ----------------------------------------------------------------------------------------------------
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# ----------------------------------------------------------------------------------------------------
#
# Finished Airport: kden
#
# ----------------------------------------------------------------------------------------------------
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# ----------------------------------------------------------------------------------------------------
#
# Finished Airport: kdfw
#
# ----------------------------------------------------------------------------------------------------
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# ----------------------------------------------------------------------------------------------------
#
# Finished Airport: kjfk
#
# ----------------------------------------------------------------------------------------------------
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# ----------------------------------------------------------------------------------------------------
#
# Finished Airport: kmem
#
# ----------------------------------------------------------------------------------------------------
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# ----------------------------------------------------------------------------------------------------
#
# Finished Airport: kmia
#
# ----------------------------------------------------------------------------------------------------
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# ----------------------------------------------------------------------------------------------------
#
# Finished Airport: kord
#
# ----------------------------------------------------------------------------------------------------
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# ----------------------------------------------------------------------------------------------------
#
# Finished Airport: kphx
#
# ----------------------------------------------------------------------------------------------------
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/spencer/opt/anaconda3/envs/nasa-comp/lib/python3.8/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# ----------------------------------------------------------------------------------------------------
#
# Finished Airport: ksea
#
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# # Train Final Model

# %%
train_final_model(MCS=False)
